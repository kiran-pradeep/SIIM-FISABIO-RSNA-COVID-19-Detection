# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

# %%
# %cd ..

# %%
# !git clone https://github.com/ultralytics/yolov5.git  # clone repo

# %%
# %cd yolov5

# %%
# %pip install -qr requirements.txt # install dependencies

# %%
# !WANDB_MODE="dryrun" python train.py --img 640 --batch 16 --epochs 18 --data ../input/siim-640x640-yaml/siim_data_640x640.yaml --hyp ../input/siim-640x640-yaml/siim640_hyp.scratch.yaml --cfg models/yolov5x.yaml --weights runs/train/siim5/weights/last.pt --name siim

# %% [markdown]
# We can see that the mAP score hover around ~0.48 after the 32nd epoch, so training again with a lower learning rate might help to get higher mAP score!

# %%
# %cd ..
# %cd working

# %%
import os
os.remove('./yolov5.tar.gz')

# %%
# %cd ..
# %cd ..

# %% [markdown]
# # **Saving the weights**

# %%
# %%time
# !tar -zcf yolov5weights.tar.gz -C "/kaggle/yolov5/runs/train/siim11/" .
#!tar -zcf labels.tar.gz -C "/kaggle/tmp/labels/" .

# %% [markdown]
# Download the tar file in the working directory.

# %%
# %cd ..
# %cd yolov5

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15, 15))
plt.imshow(plt.imread('runs/train/siim/train_batch0.jpg'))

plt.figure(figsize = (15, 15))
plt.imshow(plt.imread('runs/train/siim/train_batch1.jpg'))

plt.figure(figsize = (15, 15))
plt.imshow(plt.imread('runs/train/siim/train_batch2.jpg'))

# %%
fig, ax = plt.subplots(3, 2, figsize = (2*5,3*5), constrained_layout = True)
for row in range(3):
    ax[row][0].imshow(plt.imread(f'runs/train/siim11/test_batch{row}_labels.jpg'))
    ax[row][0].set_xticks([])
    ax[row][0].set_yticks([])
    ax[row][0].set_title(f'runs/train/siim11/test_batch{row}_labels.jpg', fontsize = 12)
    
    ax[row][1].imshow(plt.imread(f'runs/train/siim11/test_batch{row}_pred.jpg'))
    ax[row][1].set_xticks([])
    ax[row][1].set_yticks([])
    ax[row][1].set_title(f'runs/train/siim11/test_batch{row}_pred.jpg', fontsize = 12)

# %%
plt.figure(figsize=(30,15))
plt.axis('off')
plt.imshow(plt.imread('runs/train/siim5/results.png'));
